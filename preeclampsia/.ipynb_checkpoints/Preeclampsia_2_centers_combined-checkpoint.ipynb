# %%
# Linear regression on ranks for top up regulated cell types with sampled tumor fraction

# %%
# Load packages
import re
import pandas as pd
import numpy as np
import math
import os

# %%
input_dir = "/mnt/DATA3/timo/preeclampsia/main_centers/body/corr_tissues_new/"
output_dir = "/mnt/DATA3/timo/preeclampsia/main_centers/body/outputs/"

# %%
# in meta data preeclampsia 2 with ATL concentrations samp 57 is healthy (in previous meta data it was preeclampsia)
meta_dat = pd.read_csv("/mnt/DATA3/timo/data/preeclampsia_metadata_2.tsv", sep = "\t")
meta_dat = meta_dat[["sample name", "ALT_(U/l)_high_above_33", "group"]]
meta_dat = meta_dat.rename(columns={"group": "status", "sample name" : "sample", "ALT_(U/l)_high_above_33" : "ALT"})

# %%
meta_dat[meta_dat['sample'] == 'samp57']
# Out:
#     sample ALT   status
# 40  samp57  11  Healthy

# %%
# Create the empty DataFrame
columns = ["sample", "status", "ALT", "cell_type", "correlation", "rank"]
empty_df = pd.DataFrame(columns=columns)

for file in os.listdir(input_dir):
    sample = file.split('_')[0]
    filename = input_dir + file
    data = pd.read_csv(filename)
    data["sample"] = sample
    data = data.rename(columns={"correlation_mean": "correlation", "rank_mean" : "rank"})
    data_merged = pd.merge(data, meta_dat, on = "sample")
    data_merged = data_merged[columns]
    empty_df = pd.concat([empty_df, data_merged], ignore_index = True)
empty_df = empty_df.rename(columns={"cell_type": "cell_type_tissue"})
empty_df
# Out:
# /tmp/ipykernel_1037685/2124236940.py:13: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   empty_df = pd.concat([empty_df, data_merged], ignore_index = True)
#        sample        status  ALT                     cell_type_tissue  \
# 0      samp55       Healthy  NaN         RNA.classical.monocyte.Blood
# 1      samp55       Healthy  NaN            RNA.myeloid.cell.Pancreas
# 2      samp55       Healthy  NaN                  RNA.monocyte.Thymus
# 3      samp55       Healthy  NaN             RNA.monocyte.Bone.Marrow
# 4      samp55       Healthy  NaN        RNA.classical.monocyte.Spleen
# ...       ...           ...  ...                                  ...
# 20085   samp1  Preeclampsia   14  RNA.ciliated.epithelial.cell.Uterus
# 20086   samp1  Preeclampsia   14                 RNA.hepatocyte.Liver
# 20087   samp1  Preeclampsia   14       RNA.eye.photoreceptor.cell.Eye
# 20088   samp1  Preeclampsia   14          RNA.lung.ciliated.cell.Lung
# 20089   samp1  Preeclampsia   14            RNA.ciliated.cell.Trachea
#
#        correlation rank
# 0        -0.190319    1
# 1        -0.189240    2
# 2        -0.186312    3
# 3        -0.184916    4
# 4        -0.184744    5
# ...            ...  ...
# 20085    -0.011987  486
# 20086    -0.009075  487
# 20087    -0.007249  488
# 20088    -0.004713  489
# 20089     0.003010  490
#
# [20090 rows x 6 columns]

# %%
# Remove rows where the cell_type_tissue contains 'RNA.NA.' 
empty_df = empty_df[~empty_df['cell_type_tissue'].str.startswith('RNA.NA')]

# %%
empty_df[empty_df['sample'] == 'samp57']
# Out:
#        sample   status ALT                                   cell_type_tissue  \
# 13720  samp57  Healthy  11                                RNA.monocyte.Thymus
# 13721  samp57  Healthy  11                              RNA.macrophage.Kidney
# 13722  samp57  Healthy  11                        RNA.mature.NK.T.cell.Spleen
# 13723  samp57  Healthy  11                       RNA.classical.monocyte.Blood
# 13724  samp57  Healthy  11                           RNA.monocyte.Bone.Marrow
# ...       ...      ...  ..                                                ...
# 14205  samp57  Healthy  11                            RNA.keratinocyte.Tongue
# 14206  samp57  Healthy  11                     RNA.eye.photoreceptor.cell.Eye
# 14207  samp57  Healthy  11                               RNA.neutrophil.Liver
# 14208  samp57  Healthy  11                        RNA.fast.muscle.cell.Muscle
# 14209  samp57  Healthy  11  RNA.intestinal.crypt.stem.cell.of.small.intest...
#
#        correlation rank
# 13720    -0.200585    1
# 13721    -0.197917    2
# 13722    -0.193533    3
# 13723    -0.192671    4
# 13724    -0.192522    5
# ...            ...  ...
# 14205    -0.015033  486
# 14206    -0.013018  487
# 14207    -0.012634  488
# 14208    -0.009642  489
# 14209    -0.006899  490
#
# [489 rows x 6 columns]

# %%
# Function to replace dots before specific words and the last dot if no underscores are present
def replace_dot_before_words(s):
    # Replace dot before specific words (e.g., Bone, Small, etc.)
    s = re.sub(r'\.(?=Bone|Small|Large|Salivary|Lymph)', '_', s)
    
    # If no underscore is present, replace the last dot in the string with an underscore
    if '_' not in s:
        # Replace the last dot before the last word with an underscore
        s = re.sub(r'\.(?=[^\._]*$)', '_', s)
    
    return s

empty_df.loc[:, 'cell_type_tissue'] = empty_df['cell_type_tissue'].apply(replace_dot_before_words)

empty_df
# Out:
#        sample        status  ALT                     cell_type_tissue  \
# 0      samp55       Healthy  NaN         RNA.classical.monocyte_Blood
# 1      samp55       Healthy  NaN            RNA.myeloid.cell_Pancreas
# 2      samp55       Healthy  NaN                  RNA.monocyte_Thymus
# 3      samp55       Healthy  NaN             RNA.monocyte_Bone.Marrow
# 4      samp55       Healthy  NaN        RNA.classical.monocyte_Spleen
# ...       ...           ...  ...                                  ...
# 20085   samp1  Preeclampsia   14  RNA.ciliated.epithelial.cell_Uterus
# 20086   samp1  Preeclampsia   14                 RNA.hepatocyte_Liver
# 20087   samp1  Preeclampsia   14       RNA.eye.photoreceptor.cell_Eye
# 20088   samp1  Preeclampsia   14          RNA.lung.ciliated.cell_Lung
# 20089   samp1  Preeclampsia   14            RNA.ciliated.cell_Trachea
#
#        correlation rank
# 0        -0.190319    1
# 1        -0.189240    2
# 2        -0.186312    3
# 3        -0.184916    4
# 4        -0.184744    5
# ...            ...  ...
# 20085    -0.011987  486
# 20086    -0.009075  487
# 20087    -0.007249  488
# 20088    -0.004713  489
# 20089     0.003010  490
#
# [20049 rows x 6 columns]

# %%
# Function to clean the cell type strings
def clean_cell_type(cell_type):
    # Replace all "." and ".." with spaces
    cell_type = re.sub(r'\.\.+', ' ', cell_type)
    cell_type = cell_type.replace('.', ' ')
    
    # Remove "RNA" from the string
    cell_type = cell_type.replace("RNA", "")
     
    return cell_type

# Apply the function to the 'cell_type' column
empty_df.loc[:, 'cell_type_tissue'] = empty_df['cell_type_tissue'].apply(clean_cell_type)


empty_df
# Out:
#        sample        status  ALT                  cell_type_tissue  \
# 0      samp55       Healthy  NaN          classical monocyte_Blood
# 1      samp55       Healthy  NaN             myeloid cell_Pancreas
# 2      samp55       Healthy  NaN                   monocyte_Thymus
# 3      samp55       Healthy  NaN              monocyte_Bone Marrow
# 4      samp55       Healthy  NaN         classical monocyte_Spleen
# ...       ...           ...  ...                               ...
# 20085   samp1  Preeclampsia   14   ciliated epithelial cell_Uterus
# 20086   samp1  Preeclampsia   14                  hepatocyte_Liver
# 20087   samp1  Preeclampsia   14        eye photoreceptor cell_Eye
# 20088   samp1  Preeclampsia   14           lung ciliated cell_Lung
# 20089   samp1  Preeclampsia   14             ciliated cell_Trachea
#
#        correlation rank
# 0        -0.190319    1
# 1        -0.189240    2
# 2        -0.186312    3
# 3        -0.184916    4
# 4        -0.184744    5
# ...            ...  ...
# 20085    -0.011987  486
# 20086    -0.009075  487
# 20087    -0.007249  488
# 20088    -0.004713  489
# 20089     0.003010  490
#
# [20049 rows x 6 columns]

# %%
len(empty_df["cell_type_tissue"].unique())
# Out:
# 489

# %%
empty_df.to_csv(output_dir + "Ranks_FCC_RNA_cell_type_tissue_preeclampsia.csv", index=False)
