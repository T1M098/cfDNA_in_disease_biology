# %%
library(data.table)
library(tidyverse)
library(e1071)
library(pROC)
args <- commandArgs(TRUE)

# %%
myseed <- 42
cost <- 1

# %%
# Load data
data <- read.csv("/data/ranks/Ranks_FCC_RNA_cell_type_tissue_preeclampsia.csv", header = TRUE)
data <- na.omit(data)

# %%
combined <- data

# %%
combined$group <- paste0(combined$sample, ":", combined$status)
combined.wider <- combined %>% select(-sample, -status, -correlation, -ALT) %>% pivot_wider(names_from = cell_type_tissue, values_from = rank) %>% as.data.frame()
rownames(combined.wider) <- combined.wider$group
dtmat <- combined.wider %>% select(-group) %>% data.matrix()

#set seed
set.seed(myseed)

# %%
#set variables
orgroup <- row.names(dtmat)
dtmat_group <- sapply(strsplit(row.names(dtmat), split=':', fixed=TRUE), function(x) (x[2]))
dtmat_group <- as.factor(dtmat_group)

# %%
#get weights
wts <- 100 / table(dtmat_group)
n_train <- nrow(dtmat)
                      
alltruegroup <- c()
allpredgroup <- c()
allpredval <- c()
predres <- c()

# %%
feature_weights_dict <- list()
n_features <- ncol(dtmat)
feature_weights <- matrix(0, nrow = n_features, ncol = n_train)
rownames(feature_weights) <- colnames(dtmat)
colnames(feature_weights) <- paste0("LeaveOut_", 1:n_train)

# %%
#n_train <- 50                   
#run leave-one-out svm
for (x in 1:n_train) {
    traindt <- dtmat[-x,]
    traingroup <- dtmat_group[-x]
    testdt <- t(dtmat[x,])
    #train.pca <- prcomp(traindt)
    #print(dim(train.pca$x))
    #project.test <- predict(train.pca, testdt)
    testgroup <- dtmat_group[x]
    svm.model <- svm(traindt, traingroup, class.weights = wts, kernel="linear", cost=cost, scale=FALSE, decision.values=TRUE)
    
    w <- t(svm.model$coefs) %*% svm.model$SV
    feature_weights[, x] <- as.numeric(w)
    
    svm.pred <- predict(svm.model,testdt,decision.values=TRUE)
    numeric_true <- ifelse(testgroup == "Healthy", 2, 1)
    alltruegroup <- c(alltruegroup,numeric_true)
    allpredgroup <- c(allpredgroup,attributes(svm.pred)$decision.values)
    numeric_pred <- ifelse(svm.pred == "Healthy", 2, 1)
    allpredval <- c(allpredval,numeric_pred)
    predres <- rbind(predres, data.frame(orgroup[x],attributes(svm.pred)$decision.values))
    #print(data.frame(orgroup[x],svm.pred))
}

# %%
avg_weights <- rowMeans(feature_weights, na.rm = TRUE)
important_features <- data.frame(
    Feature = colnames(dtmat),
    AvgWeight = avg_weights
    ) %>% arrange(desc(AvgWeight))

# Add the cancer type to the dataframe
important_features$CancerType <- cancer_type

# Save to the dictionary
feature_weights_dict[[cancer_type]] <- important_features

# %%
# Assigne control and case levels to 1 and 2
alltruegroup <- factor(alltruegroup, levels = c(2, 1), labels = c("Control", "Preeclampsia"))
allpredval <- factor(allpredval, levels = c(2, 1), labels = c("Control", "Preeclampsia"))

# %%
#export decision values and print performance metrics
# Convert true groups to factors with specified levels
#alltruegroup <- factor(alltruegroup, levels = c("Cancer", "Control"))  # Make sure the correct labels are used
#write.table(predres, paste0(output_dir, "/svm_loo_decision_values.txt", sep="\t", row.names=F, col.names=T, quote=F)
svmperfm <- roc(response=alltruegroup,predictor=allpredgroup,ci=TRUE)
print(svmperfm$auc)
print(svmperfm$ci)
runacc <- table(alltruegroup,allpredval)
print(runacc)
acclist <- (runacc[1,1]+runacc[2,2])/sum(runacc)
print(paste0("Accuracy: ", acclist))

#plot ROC curve
#pdf(paste0(output_dir, "/svm_loo_roc.pdf"))
plot(svmperfm,print.auc=TRUE)
#dev.off()
# Out:
# Setting levels: control = Control, case = Preeclampsia
#
# Setting direction: controls > cases
# Area under the curve: 0.7368
# 95% CI: 0.5778-0.8958 (DeLong)
#               allpredval
# alltruegroup   Control Preeclampsia
#   Control           11            8
#   Preeclampsia       5           17
# [1] "Accuracy: 0.682926829268293"
# plot without title

# %%
feature_weights_df <- bind_rows(feature_weights_dict)
# Out:
#                                                           Feature
#  neutrophil_Bone Marrow                                    neutrophil_Bone Marrow
#  B cell_Large Intestine                                    B cell_Large Intestine
#  macrophage_Eye                                            macrophage_Eye
#  basophil_Blood                                            basophil_Blood
#  neutrophil_Spleen                                         neutrophil_Spleen
#  pericyte_Mammary                                          pericyte_Mammary
#  fibroblast_Thymus                                         fibroblast_Thymus
#  neutrophil_Blood                                          neutrophil_Blood
#  hematopoietic stem cell_Spleen                            hematopoietic stem cell_Spleen
#  mature NK T cell_Thymus                                   mature NK T cell_Thymus
#  mature NK T cell_Kidney                                   mature NK T cell_Kidney
#  vein endothelial cell_Mammary                             vein endothelial cell_Mammary
#  blood vessel endothelial cell_Lung                        blood vessel endothelial cell_Lung
#  gut endothelial cell_Small Intestine                      gut endothelial cell_Small Intestine
#  erythroid progenitor cell_Bone Marrow                     erythroid progenitor cell_Bone Marrow
#  adventitial cell_Salivary Gland                           adventitial cell_Salivary Gland
#  B cell_Eye                                                B cell_Eye
#  radial glial cell_Eye                                     radial glial cell_Eye
#  hematopoietic stem cell_Bone Marrow                       hematopoietic stem cell_Bone Marrow
#  smooth muscle cell_Trachea                                smooth muscle cell_Trachea
#  fibroblast of breast_Mammary                              fibroblast of breast_Mammary
#  T cell_Prostate                                           T cell_Prostate
#  platelet_Spleen                                           platelet_Spleen
#  mesenchymal stem cell_Fat                                 mesenchymal stem cell_Fat
#  CD8 positive alpha beta T cell_Muscle                     CD8 positive alpha beta T cell_Muscle
#  erythrocyte_Spleen                                        erythrocyte_Spleen
#  fibroblast_Prostate                                       fibroblast_Prostate
#  pericyte_Lung                                             pericyte_Lung
#  plasma cell_Eye                                           plasma cell_Eye
#  mature conventional dendritic cell_Lymph Node             mature conventional dendritic cell_Lymph Node
# ⋮                                                         ⋮
#  endothelial cell_Kidney                                   endothelial cell_Kidney
#  Placenta Trophoblast giant cells_Placenta                 Placenta Trophoblast giant cells_Placenta
#  capillary endothelial cell_Lung                           capillary endothelial cell_Lung
#  endothelial cell_Pancreas                                 endothelial cell_Pancreas
#  T cell_Muscle                                             T cell_Muscle
#  myofibroblast cell_Fat                                    myofibroblast cell_Fat
#  endothelial cell of lymphatic vessel_Uterus               endothelial cell of lymphatic vessel_Uterus
#  B cell_Kidney                                             B cell_Kidney
#  naive B cell_Thymus                                       naive B cell_Thymus
#  CD141 positive myeloid dendritic cell_Spleen              CD141 positive myeloid dendritic cell_Spleen
#  monocyte_Eye                                              monocyte_Eye
#  smooth muscle cell_Vasculature                            smooth muscle cell_Vasculature
#  capillary endothelial cell_Bladder                        capillary endothelial cell_Bladder
#  CD141 positive myeloid dendritic cell_Skin                CD141 positive myeloid dendritic cell_Skin
#  basal cell_Lung                                           basal cell_Lung
#  epithelial cell_Vasculature                               epithelial cell_Vasculature
#  mature NK T cell_Uterus                                   mature NK T cell_Uterus
#  Placenta Myeloid cells_Placenta                           Placenta Myeloid cells_Placenta
#  B cell_Pancreas                                           B cell_Pancreas
#  endothelial cell_Spleen                                   endothelial cell_Spleen
#  plasma cell_Large Intestine                               plasma cell_Large Intestine
#  Placenta_Lymphoid cells Placenta                          Placenta_Lymphoid cells Placenta
#  naive thymus derived CD8 positive alpha beta T cell_Skin  naive thymus derived CD8 positive alpha beta T cell_Skin
#  T cell_Uterus                                             T cell_Uterus
#  endothelial cell of artery_Lung                           endothelial cell of artery_Lung
#  fibroblast_Eye                                            fibroblast_Eye
#  medullary thymic epithelial cell_Thymus                   medullary thymic epithelial cell_Thymus
#  serous cell of epithelium of trachea_Trachea              serous cell of epithelium of trachea_Trachea
#  CD8 positive alpha beta cytotoxic T cell_Skin             CD8 positive alpha beta cytotoxic T cell_Skin
#  mature NK T cell_Bone Marrow                              mature NK T cell_Bone Marrow
#                                                           AvgWeight
#  neutrophil_Bone Marrow                                   0.003156207
#  B cell_Large Intestine                                   0.002800214
#  macrophage_Eye                                           0.002612725
#  basophil_Blood                                           0.002395316
#  neutrophil_Spleen                                        0.002393945
#  pericyte_Mammary                                         0.002391505
#  fibroblast_Thymus                                        0.002232257
#  neutrophil_Blood                                         0.002178135
#  hematopoietic stem cell_Spleen                           0.001946147
#  mature NK T cell_Thymus                                  0.001811911
#  mature NK T cell_Kidney                                  0.001794284
#  vein endothelial cell_Mammary                            0.001748378
#  blood vessel endothelial cell_Lung                       0.001746631
#  gut endothelial cell_Small Intestine                     0.001687883
#  erythroid progenitor cell_Bone Marrow                    0.001684840
#  adventitial cell_Salivary Gland                          0.001671072
#  B cell_Eye                                               0.001667760
#  radial glial cell_Eye                                    0.001662246
#  hematopoietic stem cell_Bone Marrow                      0.001632977
#  smooth muscle cell_Trachea                               0.001630822
#  fibroblast of breast_Mammary                             0.001624067
#  T cell_Prostate                                          0.001605409
#  platelet_Spleen                                          0.001602896
#  mesenchymal stem cell_Fat                                0.001600050
#  CD8 positive alpha beta T cell_Muscle                    0.001589201
#  erythrocyte_Spleen                                       0.001558452
#  fibroblast_Prostate                                      0.001482329
#  pericyte_Lung                                            0.001472873
#  plasma cell_Eye                                          0.001454934
#  mature conventional dendritic cell_Lymph Node            0.001423520
# ⋮                                                         ⋮
#  endothelial cell_Kidney                                  -0.001425995
#  Placenta Trophoblast giant cells_Placenta                -0.001443908
#  capillary endothelial cell_Lung                          -0.001454234
#  endothelial cell_Pancreas                                -0.001477046
#  T cell_Muscle                                            -0.001478607
#  myofibroblast cell_Fat                                   -0.001481686
#  endothelial cell of lymphatic vessel_Uterus              -0.001485181
#  B cell_Kidney                                            -0.001485515
#  naive B cell_Thymus                                      -0.001486273
#  CD141 positive myeloid dendritic cell_Spleen             -0.001516389
#  monocyte_Eye                                             -0.001575077
#  smooth muscle cell_Vasculature                           -0.001647215
#  capillary endothelial cell_Bladder                       -0.001662805
#  CD141 positive myeloid dendritic cell_Skin               -0.001665637
#  basal cell_Lung                                          -0.001667983
#  epithelial cell_Vasculature                              -0.001672781
#  mature NK T cell_Uterus                                  -0.001735657
#  Placenta Myeloid cells_Placenta                          -0.001793408
#  B cell_Pancreas                                          -0.001816247
#  endothelial cell_Spleen                                  -0.001874908
#  plasma cell_Large Intestine                              -0.002017062
#  Placenta_Lymphoid cells Placenta                         -0.002065193
#  naive thymus derived CD8 positive alpha beta T cell_Skin -0.002080174
#  T cell_Uterus                                            -0.002139575
#  endothelial cell of artery_Lung                          -0.002363377
#  fibroblast_Eye                                           -0.002404352
#  medullary thymic epithelial cell_Thymus                  -0.002509246
#  serous cell of epithelium of trachea_Trachea             -0.002597305
#  CD8 positive alpha beta cytotoxic T cell_Skin            -0.003026615
#  mature NK T cell_Bone Marrow                             -0.003667259
#                                                           CancerType
#  neutrophil_Bone Marrow                                   preeclampsia
#  B cell_Large Intestine                                   preeclampsia
#  macrophage_Eye                                           preeclampsia
#  basophil_Blood                                           preeclampsia
#  neutrophil_Spleen                                        preeclampsia
#  pericyte_Mammary                                         preeclampsia
#  fibroblast_Thymus                                        preeclampsia
#  neutrophil_Blood                                         preeclampsia
#  hematopoietic stem cell_Spleen                           preeclampsia
#  mature NK T cell_Thymus                                  preeclampsia
#  mature NK T cell_Kidney                                  preeclampsia
#  vein endothelial cell_Mammary                            preeclampsia
#  blood vessel endothelial cell_Lung                       preeclampsia
#  gut endothelial cell_Small Intestine                     preeclampsia
#  erythroid progenitor cell_Bone Marrow                    preeclampsia
#  adventitial cell_Salivary Gland                          preeclampsia
#  B cell_Eye                                               preeclampsia
#  radial glial cell_Eye                                    preeclampsia
#  hematopoietic stem cell_Bone Marrow                      preeclampsia
#  smooth muscle cell_Trachea                               preeclampsia
#  fibroblast of breast_Mammary                             preeclampsia
#  T cell_Prostate                                          preeclampsia
#  platelet_Spleen                                          preeclampsia
#  mesenchymal stem cell_Fat                                preeclampsia
#  CD8 positive alpha beta T cell_Muscle                    preeclampsia
#  erythrocyte_Spleen                                       preeclampsia
#  fibroblast_Prostate                                      preeclampsia
#  pericyte_Lung                                            preeclampsia
#  plasma cell_Eye                                          preeclampsia
#  mature conventional dendritic cell_Lymph Node            preeclampsia
# ⋮                                                         ⋮
#  endothelial cell_Kidney                                  preeclampsia
#  Placenta Trophoblast giant cells_Placenta                preeclampsia
#  capillary endothelial cell_Lung                          preeclampsia
#  endothelial cell_Pancreas                                preeclampsia
#  T cell_Muscle                                            preeclampsia
#  myofibroblast cell_Fat                                   preeclampsia
#  endothelial cell of lymphatic vessel_Uterus              preeclampsia
#  B cell_Kidney                                            preeclampsia
#  naive B cell_Thymus                                      preeclampsia
#  CD141 positive myeloid dendritic cell_Spleen             preeclampsia
#  monocyte_Eye                                             preeclampsia
#  smooth muscle cell_Vasculature                           preeclampsia
#  capillary endothelial cell_Bladder                       preeclampsia
#  CD141 positive myeloid dendritic cell_Skin               preeclampsia
#  basal cell_Lung                                          preeclampsia
#  epithelial cell_Vasculature                              preeclampsia
#  mature NK T cell_Uterus                                  preeclampsia
#  Placenta Myeloid cells_Placenta                          preeclampsia
#  B cell_Pancreas                                          preeclampsia
#  endothelial cell_Spleen                                  preeclampsia
#  plasma cell_Large Intestine                              preeclampsia
#  Placenta_Lymphoid cells Placenta                         preeclampsia
#  naive thymus derived CD8 positive alpha beta T cell_Skin preeclampsia
#  T cell_Uterus                                            preeclampsia
#  endothelial cell of artery_Lung                          preeclampsia
#  fibroblast_Eye                                           preeclampsia
#  medullary thymic epithelial cell_Thymus                  preeclampsia
#  serous cell of epithelium of trachea_Trachea             preeclampsia
#  CD8 positive alpha beta cytotoxic T cell_Skin            preeclampsia
#  mature NK T cell_Bone Marrow                             preeclampsia

# %%
# Save as CSV
# write.csv(feature_weights_df, "/data/feature_weights/FCC_RNA_cell_type_tissue_loosvm_feature_weights_preeclampsia.csv", row.names = FALSE)

# %%
preeclampsia <- data
dic_ct <- list(
  'preeclampsia' = data
)

# %%
# Predictions for all cancer types:
for (cancer_type in names(dic_ct)){
    print(cancer_type)

    # testing with normalized correlations values instead of ranks as features
    combined <- dic_ct[[cancer_type]]
    combined$group <- paste0(combined$sample, ":", combined$status)
    combined.wider <- combined %>% select(-sample, -status, -correlation, -ALT) %>% pivot_wider(names_from = cell_type_tissue, values_from = rank) %>% as.data.frame()
    rownames(combined.wider) <- combined.wider$group
    dtmat <- combined.wider %>% select(-group) %>% data.matrix()

    #set seed
    set.seed(myseed)

    #set variables
    orgroup <- row.names(dtmat)
    dtmat_group <- sapply(strsplit(row.names(dtmat), split=':', fixed=TRUE), function(x) (x[2]))
    dtmat_group <- as.factor(dtmat_group)

    #get weights
    wts <- 100 / table(dtmat_group)
    n_train <- nrow(dtmat)

    alltruegroup <- c()
    allpredgroup <- c()
    allpredval <- c()
    predres <- c()

    #run leave-one-out svm
    for (x in 1:n_train) {
        traindt <- dtmat[-x,]
        traingroup <- dtmat_group[-x]
        testdt <- t(dtmat[x,])
        # Perform PCA on training data
        train.pca <- prcomp(traindt, scale. = TRUE)  # Scale the data
        
        # Extract top 10 principal components for training
        train_pcs <- train.pca$x[, 1:30]
        
        # Project the test sample onto the PCA space
        project.test <- predict(train.pca, newdata = testdt)
        
        # Ensure test data is in the correct format (1-row matrix with 10 columns)
        test_pcs <- matrix(project.test[1, 1:30], nrow = 1)
        testgroup <- dtmat_group[x]
        
        # Train SVM on the 10 PCs
        svm.model <- svm(train_pcs, traingroup, class.weights = wts, kernel = "linear", cost = cost, scale = FALSE, decision.values = TRUE)
        
        # Predict using SVM
        svm.pred <- predict(svm.model, test_pcs, decision.values = TRUE)
        numeric_true <- ifelse(testgroup == "Healthy", 2, 1)
        alltruegroup <- c(alltruegroup,numeric_true)
        allpredgroup <- c(allpredgroup,attributes(svm.pred)$decision.values)
        numeric_pred <- ifelse(svm.pred == "Healthy", 2, 1)
        allpredval <- c(allpredval,numeric_pred)
        predres <- rbind(predres, data.frame(orgroup[x],attributes(svm.pred)$decision.values))
        #print(data.frame(orgroup[x],svm.pred))
    }
    
                          
    # Assigne control and case levels to 1 and 2
    alltruegroup <- factor(alltruegroup, levels = c(2, 1), labels = c("Control", "Preeclampsia"))
    allpredval <- factor(allpredval, levels = c(2, 1), labels = c("Control", "Preeclampsia"))
    #export decision values and print performance metrics
    #write.table(predres, paste0(output_dir, "/svm_loo_decision_values.txt", sep="\t", row.names=F, col.names=T, quote=F)
    svmperfm <- roc(response=alltruegroup,predictor=allpredgroup,ci=TRUE)
    print(svmperfm$auc)
    print(svmperfm$ci)
    runacc <- table(alltruegroup,allpredval)
    print(runacc)

    TP <- runacc[2,2]
    TN <- runacc[1,1]
    FP <- runacc[1,2]
    FN <-runacc[2,1]
                          
    # Calculate Accuracy
    accuracy <- (TP + TN) / (TP + TN + FP + FN)

    # Calculate Sensitivity (Recall)
    sensitivity <- TP / (TP + FN)

    # Calculate Specificity
    specificity <- TN / (TN + FP)

    # Calculate Precision
    precision <- TP / (TP + FP)

    # Calculate F1 Score
    f1_score <- 2 * (precision * sensitivity) / (precision + sensitivity)
    print(paste0("Accuracy: ", accuracy))

    #plot ROC curve
    pdf("/mnt/DATA3/timo/plots/svm_loo_roc_preeclampsia.pdf")
    plot(svmperfm,print.auc=TRUE, main = paste("ROC ", "Preeclampsia"))
    # Add performance metrics to the plot
    text(x = 0.35, y = 0.1, labels = sprintf(
        "Accuracy:      %.2f\nSensitivity:    %.2f\nSpecificity:    %.2f\nPrecision:      %.2f\nF1 Score:      %.2f",
        round(accuracy,2), round(sensitivity,2), round(specificity, 2), round(precision, 2), round(f1_score, 2)),
        pos = 4, cex = 1.0, col = "black")
    dev.off()
}
# Out:
# [1] "preeclampsia"
# Setting levels: control = Control, case = Preeclampsia
#
# Setting direction: controls > cases
# Area under the curve: 0.7249
# 95% CI: 0.562-0.8877 (DeLong)
#               allpredval
# alltruegroup   Control Preeclampsia
#   Control           13            6
#   Preeclampsia       5           17
# [1] "Accuracy: 0.731707317073171"
