# %%
rm(list=ls())
setwd("/mnt/DATA3/timo")
getwd()
# Out:
# [1] "/mnt/DATA3/timo"

# %%
#sessionInfo()  # See all loaded packages and their versions
library(Matrix)
library(Seurat)
library(SeuratObject)
# Out:
# Warning message:
# “package ‘Matrix’ was built under R version 4.3.3”
# Attaching SeuratObject
#
# Seurat v4 was just loaded with SeuratObject v5; disabling v5 assays and
# validation routines, and ensuring assays work in strict v3/v4
# compatibility mode

# %%
# Load data
tabula_sapiens <- readRDS("/mnt/DATA3/timo/data/sngl_cell_Tabula_Sapiens/981bcf57-30cb-4a85-b905-e04373432fef.rds")

# %%
dim <- dim(tabula_sapiens)
print(paste("Initial Dimension: ", dim[1], dim[2]))
# Out:
# [1] "Initial Dimension:  58482 483152"

# %%
# Subset for assay = 10x 3' v3
subset_tabula_sapiens <- subset(tabula_sapiens, subset = assay == "10x 3' v3")

# %%
dim_subset <- dim(subset_tabula_sapiens)
print(paste("Filtered for assay = 10x 3' v3, Dimension:", dim_subset[1], dim_subset[2]))
# Out:
# [1] "Filtered for assay = 10x 3' v3, Dimension: 58482 412848"

# %%
# Subset the data by excluding cells with "sperm" in the "cell type" column
subset_tabula_sapiens <- subset(subset_tabula_sapiens, subset = cell_type != "sperm")
dim_subset <- dim(subset_tabula_sapiens)
print(paste("Filtered cell_type != sperm, Dimension: ", dim_subset[1], dim_subset[2]))
# Out:
# [1] "Filtered cell_type != sperm, Dimension:  58482 412837"

# %%
# Create additional column "cell_type_tissue" by concatenating "cell_type" and "tissue_in_publication"
subset_tabula_sapiens$cell_type_tissue <- paste(subset_tabula_sapiens$cell_type, subset_tabula_sapiens$tissue_in_publication, sep = "_")
# Out:
#   [1] "macrophage_Liver"
#   [2] "monocyte_Liver"
#   [3] "endothelial cell of hepatic sinusoid_Liver"
#   [4] "liver dendritic cell_Liver"
#   [5] "mature NK T cell_Liver"
#   [6] "fibroblast_Liver"
#   [7] "hepatocyte_Liver"
#   [8] "intrahepatic cholangiocyte_Liver"
#   [9] "T cell_Liver"
#  [10] "neutrophil_Liver"
#  [11] "plasma cell_Liver"
#  [12] "macrophage_Trachea"
#  [13] "tracheal goblet cell_Trachea"
#  [14] "fibroblast_Trachea"
#  [15] "endothelial cell_Trachea"
#  [16] "smooth muscle cell_Trachea"
#  [17] "ciliated cell_Trachea"
#  [18] "ionocyte_Trachea"
#  [19] "secretory cell_Trachea"
#  [20] "T cell_Trachea"
#  [21] "basal cell_Trachea"
#  [22] "mast cell_Trachea"
#  [23] "mucus secreting cell_Trachea"
#  [24] "plasma cell_Trachea"
#  [25] "CD8-positive, alpha-beta T cell_Trachea"
#  [26] "serous cell of epithelium of trachea_Trachea"
#  [27] "B cell_Trachea"
#  [28] "CD4-positive, alpha-beta T cell_Trachea"
#  [29] "neutrophil_Trachea"
#  [30] "double-positive, alpha-beta thymocyte_Trachea"
#  [31] "erythrocyte_Blood"
#  [32] "CD4-positive, alpha-beta memory T cell_Blood"
#  [33] "CD8-positive, alpha-beta cytokine secreting effector T cell_Blood"
#  [34] "classical monocyte_Blood"
#  [35] "neutrophil_Blood"
#  [36] "naive B cell_Blood"
#  [37] "mature NK T cell_Blood"
#  [38] "memory B cell_Blood"
#  [39] "type I NK T cell_Blood"
#  [40] "CD141-positive myeloid dendritic cell_Blood"
#  [41] "CD8-positive, alpha-beta T cell_Blood"
#  [42] "plasma cell_Blood"
#  [43] "T cell_Blood"
#  [44] "platelet_Blood"
#  [45] "naive thymus-derived CD4-positive, alpha-beta T cell_Blood"
#  [46] "non-classical monocyte_Blood"
#  [47] "hematopoietic stem cell_Blood"
#  [48] "plasmacytoid dendritic cell_Blood"
#  [49] "basophil_Blood"
#  [50] "B cell_Lymph_Node"
#  [51] "effector CD8-positive, alpha-beta T cell_Lymph_Node"
#  [52] "T cell_Lymph_Node"
#  [53] "type I NK T cell_Lymph_Node"
#  [54] "effector CD4-positive, alpha-beta T cell_Lymph_Node"
#  [55] "innate lymphoid cell_Lymph_Node"
#  [56] "regulatory T cell_Lymph_Node"
#  [57] "plasma cell_Lymph_Node"
#  [58] "neutrophil_Lymph_Node"
#  [59] "classical monocyte_Lymph_Node"
#  [60] "mature NK T cell_Lymph_Node"
#  [61] "macrophage_Lymph_Node"
#  [62] "endothelial cell_Lymph_Node"
#  [63] "CD141-positive myeloid dendritic cell_Lymph_Node"
#  [64] "CD1c-positive myeloid dendritic cell_Lymph_Node"
#  [65] "intermediate monocyte_Lymph_Node"
#  [66] "hematopoietic stem cell_Lymph_Node"
#  [67] "non-classical monocyte_Lymph_Node"
#  [68] "mast cell_Lymph_Node"
#  [69] "plasmacytoid dendritic cell_Lymph_Node"
#  [70] "stromal cell_Lymph_Node"
#  [71] "erythrocyte_Lymph_Node"
#  [72] "mature conventional dendritic cell_Lymph_Node"
#  [73] "acinar cell of salivary gland_Salivary_Gland"
#  [74] "naive B cell_Salivary_Gland"
#  [75] "memory B cell_Salivary_Gland"
#  [76] "CD4-positive helper T cell_Salivary_Gland"
#  [77] "pericyte_Salivary_Gland"
#  [78] "mature NK T cell_Salivary_Gland"
#  [79] "fibroblast_Salivary_Gland"
#  [80] "endothelial cell of lymphatic vessel_Salivary_Gland"
#  [81] "adventitial cell_Salivary_Gland"
#  [82] "B cell_Salivary_Gland"
#  [83] "endothelial cell_Salivary_Gland"
#  [84] "monocyte_Salivary_Gland"
#  [85] "plasma cell_Salivary_Gland"
#  [86] "duct epithelial cell_Salivary_Gland"
#  [87] "basal cell_Salivary_Gland"
#  [88] "CD8-positive, alpha-beta T cell_Salivary_Gland"
#  [89] "neutrophil_Salivary_Gland"
#  [90] "T cell_Salivary_Gland"
#  [91] "myoepithelial cell_Salivary_Gland"
#  [92] "CD8-positive, alpha-beta memory T cell_Spleen"
#  [93] "macrophage_Spleen"
#  [94] "naive thymus-derived CD4-positive, alpha-beta T cell_Spleen"
#  [95] "intermediate monocyte_Spleen"
#  [96] "endothelial cell_Spleen"
#  [97] "memory B cell_Spleen"
#  [98] "classical monocyte_Spleen"
#  [99] "neutrophil_Spleen"
# [100] "naive B cell_Spleen"
# [101] "plasma cell_Spleen"
# [102] "CD4-positive, alpha-beta memory T cell_Spleen"
# [103] "type I NK T cell_Spleen"
# [104] "naive thymus-derived CD8-positive, alpha-beta T cell_Spleen"
# [105] "mature NK T cell_Spleen"
# [106] "innate lymphoid cell_Spleen"
# [107] "erythrocyte_Spleen"
# [108] "regulatory T cell_Spleen"
# [109] "platelet_Spleen"
# [110] "hematopoietic stem cell_Spleen"
# [111] "CD141-positive myeloid dendritic cell_Spleen"
# [112] "CD1c-positive myeloid dendritic cell_Spleen"
# [113] "epithelial cell_Tongue"
# [114] "basal cell_Tongue"
# [115] "leukocyte_Tongue"
# [116] "fibroblast_Tongue"
# [117] "vein endothelial cell_Tongue"
# [118] "pericyte_Tongue"
# [119] "endothelial cell of lymphatic vessel_Tongue"
# [120] "endothelial cell of artery_Tongue"
# [121] "capillary endothelial cell_Tongue"
# [122] "tongue muscle cell_Tongue"
# [123] "keratinocyte_Tongue"
# [124] "fibroblast of breast_Mammary"
# [125] "T cell_Mammary"
# [126] "luminal epithelial cell of mammary gland_Mammary"
# [127] "macrophage_Mammary"
# [128] "pericyte_Mammary"
# [129] "vascular associated smooth muscle cell_Mammary"
# [130] "B cell_Mammary"
# [131] "vein endothelial cell_Mammary"
# [132] "basal cell_Mammary"
# [133] "plasma cell_Mammary"
# [134] "endothelial cell of artery_Mammary"
# [135] "endothelial cell of lymphatic vessel_Mammary"
# [136] "mature NK T cell_Mammary"
# [137] "mast cell_Mammary"
# [138] "T cell_Uterus"
# [139] "fibroblast_Uterus"
# [140] "macrophage_Uterus"
# [141] "leukocyte_Uterus"
# [142] "pericyte_Uterus"
# [143] "epithelial cell of uterus_Uterus"
# [144] "endothelial cell_Uterus"
# [145] "epithelial cell_Uterus"
# [146] "ciliated epithelial cell_Uterus"
# [147] "endothelial cell of lymphatic vessel_Uterus"
# [148] "myometrial cell_Uterus"
# [149] "mature NK T cell_Uterus"
# [150] "B cell_Uterus"
# [151] "vascular associated smooth muscle cell_Uterus"
# [152] "conjunctival epithelial cell_Eye"
# [153] "monocyte_Eye"
# [154] "microglial cell_Eye"
# [155] "eye photoreceptor cell_Eye"
# [156] "Mueller cell_Eye"
# [157] "fibroblast_Eye"
# [158] "T cell_Eye"
# [159] "stem cell_Eye"
# [160] "retinal blood vessel endothelial cell_Eye"
# [161] "epithelial cell of lacrimal sac_Eye"
# [162] "keratocyte_Eye"
# [163] "B cell_Eye"
# [164] "retinal pigment epithelial cell_Eye"
# [165] "corneal epithelial cell_Eye"
# [166] "stromal cell_Eye"
# [167] "melanocyte_Eye"
# [168] "retinal bipolar neuron_Eye"
# [169] "dendritic cell_Eye"
# [170] "plasma cell_Eye"
# [171] "macrophage_Eye"
# [172] "erythroid lineage cell_Eye"
# [173] "radial glial cell_Eye"
# [174] "surface ectodermal cell_Eye"
# [175] "CD8-positive, alpha-beta T cell_Eye"
# [176] "endothelial cell_Eye"
# [177] "retina horizontal cell_Eye"
# [178] "pigmented ciliary epithelial cell_Eye"
# [179] "CD4-positive, alpha-beta T cell_Eye"
# [180] "mast cell_Eye"
# [181] "fibroblast_Fat"
# [182] "endothelial cell_Fat"
# [183] "T cell_Fat"
# [184] "macrophage_Fat"
# [185] "mature NK T cell_Fat"
# [186] "myofibroblast cell_Fat"
# [187] "leukocyte_Fat"
# [188] "plasma cell_Fat"
# [189] "mesenchymal stem cell_Fat"
# [190] "smooth muscle cell_Fat"
# [191] "neutrophil_Fat"
# [192] "mast cell_Fat"
# [193] "macrophage_Skin"
# [194] "stromal cell_Skin"
# [195] "CD8-positive, alpha-beta memory T cell_Skin"
# [196] "CD141-positive myeloid dendritic cell_Skin"
# [197] "T cell_Skin"
# [198] "mature NK T cell_Skin"
# [199] "mast cell_Skin"
# [200] "muscle cell_Skin"
# [201] "CD8-positive, alpha-beta cytotoxic T cell_Skin"
# [202] "CD1c-positive myeloid dendritic cell_Skin"
# [203] "endothelial cell_Skin"
# [204] "CD4-positive, alpha-beta memory T cell_Skin"
# [205] "naive thymus-derived CD8-positive, alpha-beta T cell_Skin"
# [206] "naive thymus-derived CD4-positive, alpha-beta T cell_Skin"
# [207] "melanocyte_Skin"
# [208] "regulatory T cell_Skin"
# [209] "epithelial cell_Skin"
# [210] "plasma cell_Skin"
# [211] "CD4-positive helper T cell_Skin"
# [212] "memory B cell_Skin"
# [213] "Langerhans cell_Skin"
# [214] "naive B cell_Skin"
# [215] "cardiac endothelial cell_Heart"
# [216] "cardiac muscle cell_Heart"
# [217] "unknown_Heart"
# [218] "smooth muscle cell_Heart"
# [219] "fibroblast of cardiac tissue_Heart"
# [220] "macrophage_Heart"
# [221] "pancreatic acinar cell_Pancreas"
# [222] "T cell_Pancreas"
# [223] "endothelial cell_Pancreas"
# [224] "myeloid cell_Pancreas"
# [225] "pancreatic stellate cell_Pancreas"
# [226] "mature NK T cell_Pancreas"
# [227] "fibroblast_Pancreas"
# [228] "B cell_Pancreas"
# [229] "pancreatic ductal cell_Pancreas"
# [230] "plasma cell_Pancreas"
# [231] "type B pancreatic cell_Pancreas"
# [232] "mast cell_Pancreas"
# [233] "basal cell of prostate epithelium_Prostate"
# [234] "epithelial cell_Prostate"
# [235] "fibroblast_Prostate"
# [236] "club cell_Prostate"
# [237] "macrophage_Prostate"
# [238] "mature NK T cell_Prostate"
# [239] "erythroid progenitor cell_Prostate"
# [240] "CD8-positive, alpha-beta T cell_Prostate"
# [241] "luminal cell of prostate epithelium_Prostate"
# [242] "endothelial cell_Prostate"
# [243] "smooth muscle cell_Prostate"
# [244] "endothelial cell_Liver"
# [245] "erythrocyte_Liver"
# [246] "macrophage_Salivary_Gland"
# [247] "salivary gland cell_Salivary_Gland"
# [248] "ionocyte_Salivary_Gland"
# [249] "adipocyte_Eye"
# [250] "retinal ganglion cell_Eye"
# [251] "T cell_Bladder"
# [252] "macrophage_Bladder"
# [253] "myofibroblast cell_Bladder"
# [254] "bladder urothelial cell_Bladder"
# [255] "capillary endothelial cell_Bladder"
# [256] "smooth muscle cell_Bladder"
# [257] "fibroblast_Bladder"
# [258] "pericyte_Bladder"
# [259] "mast cell_Bladder"
# [260] "mature NK T cell_Bladder"
# [261] "endothelial cell of lymphatic vessel_Bladder"
# [262] "vein endothelial cell_Bladder"
# [263] "B cell_Bladder"
# [264] "CD4-positive, alpha-beta T cell_Large_Intestine"
# [265] "enterocyte of epithelium of large intestine_Large_Intestine"
# [266] "monocyte_Large_Intestine"
# [267] "plasma cell_Large_Intestine"
# [268] "CD8-positive, alpha-beta T cell_Large_Intestine"
# [269] "fibroblast_Large_Intestine"
# [270] "large intestine goblet cell_Large_Intestine"
# [271] "paneth cell of colon_Large_Intestine"
# [272] "B cell_Large_Intestine"
# [273] "transit amplifying cell of colon_Large_Intestine"
# [274] "mast cell_Large_Intestine"
# [275] "gut endothelial cell_Large_Intestine"
# [276] "intestinal crypt stem cell of large intestine_Large_Intestine"
# [277] "intestinal enteroendocrine cell_Large_Intestine"
# [278] "neutrophil_Large_Intestine"
# [279] "intestinal tuft cell_Large_Intestine"
# [280] "type II pneumocyte_Lung"
# [281] "neutrophil_Lung"
# [282] "effector CD4-positive, alpha-beta T cell_Lung"
# [283] "effector CD8-positive, alpha-beta T cell_Lung"
# [284] "mature NK T cell_Lung"
# [285] "blood vessel endothelial cell_Lung"
# [286] "smooth muscle cell_Lung"
# [287] "adventitial cell_Lung"
# [288] "macrophage_Lung"
# [289] "respiratory goblet cell_Lung"
# [290] "T cell_Prostate"
# [291] "neutrophil_Prostate"
# [292] "myeloid cell_Prostate"
# [293] "mast cell_Prostate"
# [294] "CD4-positive, alpha-beta T cell_Small_Intestine"
# [295] "enterocyte of epithelium of small intestine_Small_Intestine"
# [296] "neutrophil_Small_Intestine"
# [297] "transit amplifying cell of small intestine_Small_Intestine"
# [298] "small intestine goblet cell_Small_Intestine"
# [299] "CD8-positive, alpha-beta T cell_Small_Intestine"
# [300] "B cell_Small_Intestine"
# [301] "monocyte_Small_Intestine"
# [302] "paneth cell of epithelium of small intestine_Small_Intestine"
# [303] "intestinal tuft cell_Small_Intestine"
# [304] "plasma cell_Small_Intestine"
# [305] "mast cell_Small_Intestine"
# [306] "fibroblast_Small_Intestine"
# [307] "intestinal enteroendocrine cell_Small_Intestine"
# [308] "gut endothelial cell_Small_Intestine"
# [309] "intestinal crypt stem cell of small intestine_Small_Intestine"
# [310] "smooth muscle cell_Skin"
# [311] "cell of skeletal muscle_Skin"
# [312] "DN3 thymocyte_Thymus"
# [313] "DN1 thymic pro-T cell_Thymus"
# [314] "innate lymphoid cell_Thymus"
# [315] "plasma cell_Thymus"
# [316] "vascular associated smooth muscle cell_Thymus"
# [317] "endothelial cell of artery_Thymus"
# [318] "macrophage_Thymus"
# [319] "DN4 thymocyte_Thymus"
# [320] "medullary thymic epithelial cell_Thymus"
# [321] "capillary endothelial cell_Thymus"
# [322] "fibroblast_Thymus"
# [323] "vein endothelial cell_Thymus"
# [324] "B cell_Thymus"
# [325] "monocyte_Thymus"
# [326] "endothelial cell of lymphatic vessel_Thymus"
# [327] "mature NK T cell_Thymus"
# [328] "erythrocyte_Thymus"
# [329] "myeloid dendritic cell_Thymus"
# [330] "Schwann cell_Tongue"
# [331] "granulocyte_Bone_Marrow"
# [332] "neutrophil_Bone_Marrow"
# [333] "CD4-positive, alpha-beta T cell_Bone_Marrow"
# [334] "monocyte_Bone_Marrow"
# [335] "erythrocyte_Bone_Marrow"
# [336] "mature NK T cell_Bone_Marrow"
# [337] "erythroid progenitor cell_Bone_Marrow"
# [338] "memory B cell_Bone_Marrow"
# [339] "plasma cell_Bone_Marrow"
# [340] "CD8-positive, alpha-beta T cell_Bone_Marrow"
# [341] "naive B cell_Bone_Marrow"
# [342] "common myeloid progenitor_Bone_Marrow"
# [343] "hematopoietic stem cell_Bone_Marrow"
# [344] "mesenchymal stem cell_Muscle"
# [345] "skeletal muscle satellite stem cell_Muscle"
# [346] "smooth muscle cell_Muscle"
# [347] "capillary endothelial cell_Muscle"
# [348] "pericyte_Muscle"
# [349] "fast muscle cell_Muscle"
# [350] "macrophage_Muscle"
# [351] "endothelial cell of vascular tree_Muscle"
# [352] "CD4-positive, alpha-beta T cell_Muscle"
# [353] "CD8-positive, alpha-beta T cell_Muscle"
# [354] "slow muscle cell_Muscle"
# [355] "endothelial cell of artery_Muscle"
# [356] "tendon cell_Muscle"
# [357] "mature NK T cell_Muscle"
# [358] "T cell_Muscle"
# [359] "endothelial cell of lymphatic vessel_Muscle"
# [360] "mast cell_Muscle"
# [361] "erythrocyte_Muscle"
# [362] "mesothelial cell_Muscle"
# [363] "fibroblast_Vasculature"
# [364] "smooth muscle cell_Vasculature"
# [365] "macrophage_Vasculature"
# [366] "pericyte_Vasculature"
# [367] "endothelial cell of artery_Vasculature"
# [368] "erythrocyte_Vasculature"
# [369] "T cell_Vasculature"
# [370] "mast cell_Vasculature"
# [371] "B cell_Vasculature"
# [372] "mature NK T cell_Vasculature"
# [373] "plasma cell_Vasculature"
# [374] "endothelial cell of lymphatic vessel_Vasculature"
# [375] "endothelial cell_Vasculature"
# [376] "plasma cell_Bladder"
# [377] "plasmacytoid dendritic cell_Bladder"
# [378] "CD4-positive, alpha-beta T cell_Blood"
# [379] "monocyte_Blood"
# [380] "plasmablast_Blood"
# [381] "common myeloid progenitor_Blood"
# [382] "macrophage_Blood"
# [383] "granulocyte_Blood"
# [384] "kidney epithelial cell_Kidney"
# [385] "B cell_Kidney"
# [386] "CD8-positive, alpha-beta T cell_Kidney"
# [387] "endothelial cell_Kidney"
# [388] "macrophage_Kidney"
# [389] "mature NK T cell_Kidney"
# [390] "CD4-positive helper T cell_Kidney"
# [391] "enterocyte_Large_Intestine"
# [392] "intestinal crypt stem cell_Large_Intestine"
# [393] "goblet cell_Large_Intestine"
# [394] "basophil_Lung"
# [395] "classical monocyte_Lung"
# [396] "endothelial cell of artery_Lung"
# [397] "lung ciliated cell_Lung"
# [398] "dendritic cell_Lung"
# [399] "CD4-positive, alpha-beta T cell_Lung"
# [400] "basal cell_Lung"
# [401] "plasma cell_Lung"
# [402] "B cell_Lung"
# [403] "CD8-positive, alpha-beta T cell_Lung"
# [404] "serous cell of epithelium of bronchus_Lung"
# [405] "non-classical monocyte_Lung"
# [406] "capillary endothelial cell_Lung"
# [407] "type I pneumocyte_Lung"
# [408] "vein endothelial cell_Lung"
# [409] "fibroblast_Lung"
# [410] "endothelial cell of lymphatic vessel_Lung"
# [411] "bronchial smooth muscle cell_Lung"
# [412] "plasmacytoid dendritic cell_Lung"
# [413] "club cell_Lung"
# [414] "lung microvascular endothelial cell_Lung"
# [415] "vascular associated smooth muscle cell_Lung"
# [416] "myofibroblast cell_Lung"
# [417] "pericyte_Lung"
# [418] "mesothelial cell_Lung"
# [419] "intermediate monocyte_Lung"
# [420] "pulmonary ionocyte_Lung"
# [421] "naive B cell_Lymph_Node"
# [422] "memory B cell_Lymph_Node"
# [423] "naive thymus-derived CD4-positive, alpha-beta T cell_Lymph_Node"
# [424] "CD4-positive, alpha-beta memory T cell_Lymph_Node"
# [425] "CD8-positive, alpha-beta memory T cell_Lymph_Node"
# [426] "pancreatic PP cell_Pancreas"
# [427] "pancreatic A cell_Pancreas"
# [428] "pancreatic D cell_Pancreas"
# [429] "intestinal crypt stem cell_Small_Intestine"
# [430] "enterocyte_Small_Intestine"
# [431] "goblet cell_Small_Intestine"
# [432] "duodenum glandular cell_Small_Intestine"
# [433] "CD8-positive, alpha-beta T cell_Spleen"
# [434] "plasmacytoid dendritic cell_Spleen"
# [435] "CD8-positive, alpha-beta T cell_Thymus"
# [436] "memory B cell_Thymus"
# [437] "naive B cell_Thymus"
# [438] "CD4-positive helper T cell_Thymus"
# [439] "mesothelial cell_Thymus"
# [440] "fast muscle cell_Thymus"
# [441] "dendritic cell_Thymus"
# [442] "immature natural killer cell_Thymus"
# [443] "thymocyte_Thymus"
# [444] "mast cell_Thymus"
# [445] "goblet cell_Trachea"
# [446] "connective tissue cell_Trachea"
# [447] "epithelial cell_Vasculature"
# [1] 447

# %%
# Save filtered Seurat Object
saveRDS(subset_tabula_sapiens, file = "/mnt/DATA3/timo/data/sngl_cell_Tabula_Sapiens/Tabula_Sapiens_filtered.rds")

# %%
tabula_sapiens <- readRDS("/mnt/DATA3/timo/data/sngl_cell_Tabula_Sapiens/Tabula_Sapiens_filtered.rds")

# %%
library(dplyr)
test <- tabula_sapiens@meta.data %>% select(compartment, cell_type, cell_type_tissue)
# Out:
# Warning message:
# “package ‘dplyr’ was built under R version 4.3.3”
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
final <- test[!duplicated(test$cell_type_tissue), ]

# %%
write.csv(final, "/mnt/DATA3/timo/data/compartment_map.csv", row.names = FALSE)
test <- read.csv("/mnt/DATA3/timo/data/compartment_map.csv")
test
# Out:
#     compartment cell_type
# 1   immune      macrophage
# 2   immune      monocyte
# 3   endothelial endothelial cell of hepatic sinusoid
# 4   immune      liver dendritic cell
# 5   immune      mature NK T cell
# 6   stromal     fibroblast
# 7   epithelial  hepatocyte
# 8   epithelial  intrahepatic cholangiocyte
# 9   immune      T cell
# 10  immune      neutrophil
# 11  immune      plasma cell
# 12  immune      macrophage
# 13  epithelial  tracheal goblet cell
# 14  stromal     fibroblast
# 15  endothelial endothelial cell
# 16  stromal     smooth muscle cell
# 17  epithelial  ciliated cell
# 18  epithelial  ionocyte
# 19  epithelial  secretory cell
# 20  immune      T cell
# 21  epithelial  basal cell
# 22  immune      mast cell
# 23  epithelial  mucus secreting cell
# 24  immune      plasma cell
# 25  immune      CD8-positive, alpha-beta T cell
# 26  epithelial  serous cell of epithelium of trachea
# 27  immune      B cell
# 28  immune      CD4-positive, alpha-beta T cell
# 29  immune      neutrophil
# 30  immune      double-positive, alpha-beta thymocyte
# ⋮   ⋮           ⋮
# 418 stromal     mesothelial cell
# 419 immune      intermediate monocyte
# 420 epithelial  pulmonary ionocyte
# 421 immune      naive B cell
# 422 immune      memory B cell
# 423 immune      naive thymus-derived CD4-positive, alpha-beta T cell
# 424 immune      CD4-positive, alpha-beta memory T cell
# 425 immune      CD8-positive, alpha-beta memory T cell
# 426 epithelial  pancreatic PP cell
# 427 epithelial  pancreatic A cell
# 428 epithelial  pancreatic D cell
# 429 epithelial  intestinal crypt stem cell
# 430 epithelial  enterocyte
# 431 epithelial  goblet cell
# 432 epithelial  duodenum glandular cell
# 433 immune      CD8-positive, alpha-beta T cell
# 434 immune      plasmacytoid dendritic cell
# 435 immune      CD8-positive, alpha-beta T cell
# 436 immune      memory B cell
# 437 immune      naive B cell
# 438 immune      CD4-positive helper T cell
# 439 epithelial  mesothelial cell
# 440 stromal     fast muscle cell
# 441 immune      dendritic cell
# 442 immune      immature natural killer cell
# 443 immune      thymocyte
# 444 immune      mast cell
# 445 epithelial  goblet cell
# 446 stromal     connective tissue cell
# 447 epithelial  epithelial cell
#     cell_type_tissue
# 1   macrophage_Liver
# 2   monocyte_Liver
# 3   endothelial cell of hepatic sinusoid_Liver
# 4   liver dendritic cell_Liver
# 5   mature NK T cell_Liver
# 6   fibroblast_Liver
# 7   hepatocyte_Liver
# 8   intrahepatic cholangiocyte_Liver
# 9   T cell_Liver
# 10  neutrophil_Liver
# 11  plasma cell_Liver
# 12  macrophage_Trachea
# 13  tracheal goblet cell_Trachea
# 14  fibroblast_Trachea
# 15  endothelial cell_Trachea
# 16  smooth muscle cell_Trachea
# 17  ciliated cell_Trachea
# 18  ionocyte_Trachea
# 19  secretory cell_Trachea
# 20  T cell_Trachea
# 21  basal cell_Trachea
# 22  mast cell_Trachea
# 23  mucus secreting cell_Trachea
# 24  plasma cell_Trachea
# 25  CD8-positive, alpha-beta T cell_Trachea
# 26  serous cell of epithelium of trachea_Trachea
# 27  B cell_Trachea
# 28  CD4-positive, alpha-beta T cell_Trachea
# 29  neutrophil_Trachea
# 30  double-positive, alpha-beta thymocyte_Trachea
# ⋮   ⋮
# 418 mesothelial cell_Lung
# 419 intermediate monocyte_Lung
# 420 pulmonary ionocyte_Lung
# 421 naive B cell_Lymph_Node
# 422 memory B cell_Lymph_Node
# 423 naive thymus-derived CD4-positive, alpha-beta T cell_Lymph_Node
# 424 CD4-positive, alpha-beta memory T cell_Lymph_Node
# 425 CD8-positive, alpha-beta memory T cell_Lymph_Node
# 426 pancreatic PP cell_Pancreas
# 427 pancreatic A cell_Pancreas
# 428 pancreatic D cell_Pancreas
# 429 intestinal crypt stem cell_Small_Intestine
# 430 enterocyte_Small_Intestine
# 431 goblet cell_Small_Intestine
# 432 duodenum glandular cell_Small_Intestine
# 433 CD8-positive, alpha-beta T cell_Spleen
# 434 plasmacytoid dendritic cell_Spleen
# 435 CD8-positive, alpha-beta T cell_Thymus
# 436 memory B cell_Thymus
# 437 naive B cell_Thymus
# 438 CD4-positive helper T cell_Thymus
# 439 mesothelial cell_Thymus
# 440 fast muscle cell_Thymus
# 441 dendritic cell_Thymus
# 442 immature natural killer cell_Thymus
# 443 thymocyte_Thymus
# 444 mast cell_Thymus
# 445 goblet cell_Trachea
# 446 connective tissue cell_Trachea
# 447 epithelial cell_Vasculature
